# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Python310\\lib\\site-packages\\pandas\\__init__.py'>

# %%
housing=pd.read_csv('housing data csv.csv')

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
housing.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
housing['CHAS'].value_counts()
# Out:
# 0    471
# 1     35
# Name: CHAS, dtype: int64

# %%
housing['CHAS']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 501    0
# 502    0
# 503    0
# 504    0
# 505    0
# Name: CHAS, Length: 506, dtype: int64

# %%
housing
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
housing['CHAS']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 501    0
# 502    0
# 503    0
# 504    0
# 505    0
# Name: CHAS, Length: 506, dtype: int64

# %%
housing.CHAS
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 501    0
# 502    0
# 503    0
# 504    0
# 505    0
# Name: CHAS, Length: 506, dtype: int64

# %%
housing.keys()
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
housing['CHAS'].value_counts()
# Out:
# 0    471
# 1     35
# Name: CHAS, dtype: int64

# %%
housing['RAD'].value_counts()
# Out:
# 24    132
# 5     115
# 4     110
# 3      38
# 6      26
# 2      24
# 8      24
# 1      20
# 7      17
# Name: RAD, dtype: int64

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
# housing.hist(bins=50,figsize=(20,15))

# %%
from sklearn.model_selection import train_test_split,StratifiedShuffleSplit
import numpy as np

# %%
def split_train_test_fun(data,test_ratio):
    np.random.seed(10)
    shuffled=np.random.permutation(len(data))
#     print(shuffled)
    test_set_size=int(len(data)*test_ratio)
    test_indices=shuffled[:test_set_size]
    train_indices=shuffled[test_set_size:]
    return data.iloc[train_indices],data.iloc[test_indices]

# %%
train_set,test_set=split_train_test_fun(housing,0.2)

# %%
train_set,test_set=train_test_split(housing,test_size=0.2,random_state=42)

# %%
strat_split=StratifiedShuffleSplit(n_splits=1,test_size=0.2,random_state=42)
for train_index,test_index in strat_split.split(housing,housing['CHAS']):
    strat_train_set=housing.loc[train_index]
    strat_test_set=housing.loc[test_index]

# %%
strat_test_set
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 342   0.02498   0.0   1.89     0  0.518  6.540   59.7  6.2669    1  422
# 379  17.86670   0.0  18.10     0  0.671  6.223  100.0  1.3861   24  666
# 223   0.61470   0.0   6.20     0  0.507  6.618   80.8  3.2721    8  307
# 219   0.11425   0.0  13.89     1  0.550  6.373   92.4  3.3633    5  276
# 48    0.25387   0.0   6.91     0  0.448  5.399   95.3  5.8700    3  233
# ..        ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 88    0.05660   0.0   3.41     0  0.489  7.007   86.3  3.4217    2  270
# 466   3.77498   0.0  18.10     0  0.655  5.952   84.7  2.8715   24  666
# 52    0.05360  21.0   5.64     0  0.439  6.511   21.1  6.8147    4  243
# 121   0.07165   0.0  25.65     0  0.581  6.004   84.1  2.1974    2  188
# 218   0.11069   0.0  13.89     1  0.550  5.951   93.8  2.8893    5  276
#
#      PTRATIO       B  LSTAT  MEDV
# 342     15.9  389.96   8.65  16.5
# ...

# %%
strat_test_set['CHAS'].value_counts()
# Out:
# 0    95
# 1     7
# Name: CHAS, dtype: int64

# %%
strat_train_set['CHAS'].value_counts()
# Out:
# 0    376
# 1     28
# Name: CHAS, dtype: int64

# %%
corr_matrix=housing.corr()

# %%
corr_matrix
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
corr_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.695360
# ZN         0.360445
# B          0.333461
# DIS        0.249929
# CHAS       0.175260
# AGE       -0.376955
# RAD       -0.381626
# CRIM      -0.388305
# NOX       -0.427321
# TAX       -0.468536
# INDUS     -0.483725
# PTRATIO   -0.507787
# LSTAT     -0.737663
# Name: MEDV, dtype: float64

# %%
from pandas.plotting import scatter_matrix

# %%
attributes=['MEDV','RM','ZN','LSTAT']
# scatter_matrix(housing[attributes],figsize=(12,8))

# %%
housing.plot(kind="scatter",x="RM",y="MEDV",alpha=1)
# Out:
# <AxesSubplot: xlabel='RM', ylabel='MEDV'>

# %%
housing.plot(kind="scatter",x="CRIM",y="MEDV",alpha=1)
# Out:
# <AxesSubplot: xlabel='CRIM', ylabel='MEDV'>

# %%
housing['TAXRM']=housing['TAX']/housing['RM']

# %%
housing.TAXRM
# Out:
# 0      45.019011
# 1      37.688834
# 2      33.681280
# 3      31.723350
# 4      31.061984
#          ...
# 501    41.407553
# 502    44.607843
# 503    39.134174
# 504    40.182514
# 505    45.273632
# Name: TAXRM, Length: 506, dtype: float64

# %%
housing.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV      TAXRM
# 0  396.90   4.98  24.0  45.019011
# 1  396.90   9.14  21.6  37.688834
# 2  392.83   4.03  34.7  33.681280
# 3  394.63   2.94  33.4  31.723350
# 4  396.90   5.33  36.2  31.061984

# %%
corr_matrix=housing.corr()
corr_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.695360
# ZN         0.360445
# B          0.333461
# DIS        0.249929
# CHAS       0.175260
# AGE       -0.376955
# RAD       -0.381626
# CRIM      -0.388305
# NOX       -0.427321
# TAX       -0.468536
# INDUS     -0.483725
# PTRATIO   -0.507787
# TAXRM     -0.537650
# LSTAT     -0.737663
# Name: MEDV, dtype: float64

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
#  14  TAXRM    506 non-null    float64
# dtypes: float64(12), int64(3)
# memory usage: 59.4 KB

# %%
housing.plot(kind="scatter",x="TAXRM",y="MEDV",alpha=1)
# Out:
# <AxesSubplot: xlabel='TAXRM', ylabel='MEDV'>

# %%
housing=strat_train_set.drop('MEDV',axis=1)
housing_label=strat_train_set['MEDV'].copy()

# %%
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
my_pipeline=Pipeline([
    ('imputer',SimpleImputer(strategy="median")),
    ('std_scaler',StandardScaler())
])

# %%
housing_num=my_pipeline.fit_transform(housing)

# %%
housing_num.shape
# Out:
# (404, 13)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
# model=DecisionTreeRegressor()
# model=LinearRegression()
model=RandomForestRegressor()
model.fit(housing_num,housing_label)
# Out:
# RandomForestRegressor()

# %%
some_data=housing.iloc[5:10]

# %%
some_label=housing_label.iloc[5:10]

# %%
prep_data=my_pipeline.transform(some_data)

# %%
model.predict(prep_data)
# Out:
# array([16.555, 24.492, 27.047, 10.686, 31.962])

# %%
some_label
# Out:
# 411    17.2
# 250    24.4
# 100    27.5
# 429     9.5
# 57     31.6
# Name: MEDV, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
housing_predict=model.predict(housing_num)

# %%
mse=mean_squared_error(housing_label,housing_predict)

# %%
mse
# Out:
# 1.394642903465344

# %%
model.score(housing_num,housing_label)
# Out:
# 0.9841283671442588

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(model,housing_num,housing_label,scoring="neg_mean_squared_error",cv=20)
rmse_score=np.sqrt(-score)

# %%
rmse_score
# Out:
# array([2.7220248 , 2.81831811, 3.63489563, 2.18087916, 5.88866306,
#        2.46716219, 2.80909253, 2.38068127, 3.83582444, 2.91283729,
#        2.34821217, 2.75540294, 3.62168949, 4.96927507, 3.6072317 ,
#        2.89201433, 4.01756174, 2.01079344, 3.94416275, 2.22195773])

# %%
rmse_score.std()
# Out:
# 0.9685973830988994

# %%
rmse_score.mean()
# Out:
# 3.2019339908430133

# %%
model.predict(housing_num)
# Out:
# array([22.513, 25.589, 16.537, 23.406, 23.47 , 16.555, 24.492, 27.047,
#        10.686, 31.962, 15.498, 18.467, 10.97 , 34.489, 23.09 , 14.068,
#        18.904, 17.81 ,  6.906, 20.333, 18.75 , 16.835, 18.185, 28.278,
#        24.201, 24.867, 13.298, 20.97 , 14.982, 27.757, 14.869, 18.107,
#        11.337, 13.067, 20.45 , 26.712, 23.426, 47.191, 32.98 , 20.157,
#        21.832, 34.935, 36.786,  9.676, 19.914, 12.802, 21.616, 28.73 ,
#        22.784,  7.724, 24.584, 22.903, 24.006, 30.555, 14.848, 37.231,
#        21.511, 25.193, 33.724, 18.053, 19.722, 20.141, 27.686, 20.852,
#        14.178, 31.748, 49.895, 14.588, 26.771, 35.004, 22.592, 35.683,
#        22.847, 10.036, 20.663, 28.124, 25.381, 15.261, 16.113, 18.645,
#        30.665,  8.712, 19.403, 18.626, 25.257, 23.255, 29.881, 24.845,
#        29.232, 16.527, 23.082, 30.028, 27.948, 20.294, 21.549, 34.187,
#        28.679, 19.568, 23.187, 17.668, 13.104, 46.071, 20.411, 43.819,
# ...

# %%
model.score(housing_num,housing_label)
# Out:
# 0.9841283671442588

# %%
from joblib import dump,load
dump(model,'Project.joblib')
# Out:
# ['Project.joblib']

# %%
x_test=strat_test_set.drop("MEDV",axis=1)
y_test=strat_test_set['MEDV'].copy()

# %%
x_test_prepared=my_pipeline.transform(x_test)
final_predict=model.predict(x_test_prepared)

# %%
final_mse=mean_squared_error(y_test,final_predict)
final_rmse=np.sqrt(final_mse)

# %%
final_mse
# Out:
# 8.417030088235293

# %%
final_rmse
# Out:
# 2.9012118309829247

# %%
model.score(x_test_prepared,y_test)
# Out:
# 0.881017423831314
